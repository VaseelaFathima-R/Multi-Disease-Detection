# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"F:\Project_3\parkinsons - parkinsons.csv")

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
# Plot histograms for a selection of features
df[['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)']].hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# Plot boxplots to check for outliers
plt.figure(figsize=(15, 10))
sns.boxplot(data=df[['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)']])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.countplot(x='status', data=df)
plt.title("Distribution of Parkinson's Status")
plt.show()

# %%
#PreProcessing 
#Missing value:
print(df.isnull().sum())
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
#Identity of oultliers:
# Columns to check for outliers
columns_to_check = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)']

# Initialize a dictionary to store outliers for each column
outlier_dict = {}

# Detect outliers for each column using IQR
for col in columns_to_check:
    Q1 = df[col].quantile(0.25)  # First quartile (25th percentile)
    Q3 = df[col].quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1                # Interquartile range
    
    # Calculate lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Extract outliers
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
    outlier_dict[col] = outliers.tolist()  # Store outlier values in the dictionary

# Display outlier results
for col, outliers in outlier_dict.items():
    print(f"Outliers in {col}: {outliers}")
# Out:
# Outliers in MDVP:Fo(Hz): []
# Outliers in MDVP:Fhi(Hz): [588.518, 586.567, 492.892, 442.557, 450.247, 442.824, 479.697, 565.74, 592.03, 581.289, 396.961]
# Outliers in MDVP:Flo(Hz): [225.227, 232.483, 232.435, 227.911, 231.848, 223.634, 229.256, 237.303, 239.17]
# Outliers in MDVP:Jitter(%): [0.01378, 0.01936, 0.03316, 0.01551, 0.03011, 0.01568, 0.01466, 0.01719, 0.01627, 0.01872, 0.03107, 0.02714, 0.01813, 0.0136]

# %%
# Replace outliers with the bounds
for col in ['MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)']:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Cap/floor outliers
    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

print("Outliers capped/floored.")
plt.figure(figsize=(15, 10))
sns.boxplot(data=df[['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)']])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Outliers capped/floored.

# %%
# Extract outliers into a separate dataframe
outlier_df = df[(df['MDVP:Fhi(Hz)'].isin(outlier_dict['MDVP:Fhi(Hz)'])) |
                (df['MDVP:Flo(Hz)'].isin(outlier_dict['MDVP:Flo(Hz)'])) |
                (df['MDVP:Jitter(%)'].isin(outlier_dict['MDVP:Jitter(%)']))]

print("Outliers dataset:")
print(outlier_df)
# Out:
# Outliers dataset:
# Empty DataFrame
# Columns: [name, MDVP:Fo(Hz), MDVP:Fhi(Hz), MDVP:Flo(Hz), MDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP, MDVP:Shimmer, MDVP:Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, MDVP:APQ, Shimmer:DDA, NHR, HNR, status, RPDE, DFA, spread1, spread2, D2, PPE]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Step 1: Drop both 'status' (target) and 'name' (feature) from the DataFrame
X = df.drop(columns=['status', 'name'])  # Drop both target and name column
y = df['status']  # Target - 'status' column

# Now X contains the features (excluding 'status' and 'name') and y contains the target
print("Features (X) after dropping 'name' and 'status':")
print(X.head())

print("\nTarget (y):")
print(y.head())
# Out:
# Features (X) after dropping 'name' and 'status':
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Step 1: Drop 'status' and 'name' from the DataFrame
X = df.drop(columns=['status', 'name'])  # Features - all columns except 'status' and 'name'
y = df['status']  # Target - 'status' column

# Step 2: Apply StandardScaler to the features
scaler = StandardScaler()

# Fit and transform the feature columns (X) to standardize them
X_scaled = scaler.fit_transform(X)

# If you want to convert the scaled features back to a DataFrame for easier viewing:
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

print("Scaled Features (X) after applying StandardScaler:")
print(X_scaled_df.head())
# Out:
# Scaled Features (X) after applying StandardScaler:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0    -0.829300     -0.500094     -0.964110        0.701875          0.749759
# 1    -0.770972     -0.638805     -0.050885        1.308591          1.037674
# 2    -0.909476     -0.919993     -0.104142        1.578975          1.325589
# 3    -0.909622     -0.811616     -0.108588        1.404215          1.325589
# 4    -0.925657     -0.748930     -0.125313        2.350560          1.901418
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0  0.132963  0.760800    0.131755      0.745985          0.739536  ...
# 1  0.453892  1.276809    0.452684      1.681731          1.768464  ...
# 2  0.720770  1.585687    0.721813      1.202693          1.027636  ...
# 3  0.578885  1.284076    0.577677      1.340396          1.207698  ...
# 4  1.095750  2.047187    1.096793      1.836448          1.552389  ...
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# Step 1: Split the dataset into training and testing sets (if not done earlier)
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)

# Step 2: Initialize the SVC
rf_model = SVC()


# Step 3: Train the model
rf_model.fit(X_train, y_train)

# Step 4: Make predictions on the test set
y_pred_rf = rf_model.predict(X_test)

# Step 5: Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("SVM Model Accuracy:", accuracy_rf)

# Step 6: Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))

# Step 7: Confusion Matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# SVM Model Accuracy: 0.8813559322033898
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.53      0.70        15
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.88        59
#    macro avg       0.93      0.77      0.81        59
# weighted avg       0.90      0.88      0.87        59
#
#
# Confusion Matrix:
# [[ 8  7]
#  [ 0 44]]

# %%
import numpy as np

# Input data for prediction (a tuple of feature values)
input_data = (197.07600, 206.89600, 192.05500, 0.00289, 0.00001, 0.00166, 0.00168, 0.00498, 0.01098, 0.09700, 0.00563, 0.00680, 0.00802, 0.01689, 0.00339, 26.77500, 0.422229, 0.741367, -7.348300, 0.177551, 1.743867, 0.085569)

# Changing input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the numpy array to match the model's input shape
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

# Make the prediction using the trained model
prediction = rf_model.predict(input_data_reshaped)

# Print the prediction
if prediction[0] == 0:
    print("The Person does not have Parkinson's Disease")
else:
    print("The Person has Parkinson's Disease")
# Out:
# The Person has Parkinson's Disease
# C:\Users\mzraj\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle

# Assuming rf_model is your trained RandomForest model

# Save the trained model to 'parkinson_random.pkl' file
with open('F:\Project_3\parkinson_random.pkl', 'wb') as file:
    pickle.dump(rf_model, file)

print("Model saved as parkinson_random.pkl")
# Out:
# Model saved as parkinson_random.pkl
# <>:6: SyntaxWarning: invalid escape sequence '\P'
# <>:6: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mzraj\AppData\Local\Temp\ipykernel_10452\3076632409.py:6: SyntaxWarning: invalid escape sequence '\P'
#   with open('F:\Project_3\parkinson_random.pkl', 'wb') as file:

# %%
import pickle

# Load the saved model from the 'parkinson_random.pkl' file
with open('F:\Project_3\parkinson_random.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Use the loaded model for prediction
prediction = loaded_model.predict(input_data_reshaped)

if prediction[0] == 0:
    print("The Person does not have Parkinson's Disease")
else:
    print("The Person has Parkinson's Disease")
# Out:
# The Person has Parkinson's Disease
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mzraj\AppData\Local\Temp\ipykernel_10452\2831416624.py:4: SyntaxWarning: invalid escape sequence '\P'
#   with open('F:\Project_3\parkinson_random.pkl', 'rb') as file:
# C:\Users\mzraj\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
